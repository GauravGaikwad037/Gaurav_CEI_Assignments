# %% [markdown]
# # E-Commerce Sales Database Analysis
#
# ## Celebal Summer Internship 2026
#
# Week 2 Assignment

# %% [markdown]
# # Importing Required Libraries

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# # Creating Database Connection

# %%
conn = sqlite3.connect("ecommerce.db")

cursor = conn.cursor()

print("Database Connected Successfully")
# Out:
# Database Connected Successfully

# %% [markdown]
# # Creating Database Tables

# %%
cursor.execute("""
CREATE TABLE customers (
    customer_id INTEGER PRIMARY KEY,
    first_name TEXT NOT NULL,
    last_name TEXT NOT NULL,
    email TEXT UNIQUE NOT NULL,
    city TEXT NOT NULL,
    state TEXT NOT NULL,
    join_date DATE NOT NULL,
    is_premium BOOLEAN DEFAULT FALSE
)
""")

# %%
cursor.execute("""
CREATE TABLE products (
    product_id INTEGER PRIMARY KEY,
    product_name TEXT NOT NULL,
    category TEXT NOT NULL,
    brand TEXT NOT NULL,
    unit_price REAL NOT NULL,
    stock_qty INTEGER NOT NULL
)
""")

# %%
cursor.execute("""
CREATE TABLE orders (
    order_id INTEGER PRIMARY KEY,
    customer_id INTEGER,
    order_date DATE,
    status TEXT,
    total_amount REAL,
    FOREIGN KEY(customer_id)
    REFERENCES customers(customer_id)
)
""")

# %%
cursor.execute("""
CREATE TABLE order_items (
    item_id INTEGER PRIMARY KEY,
    order_id INTEGER,
    product_id INTEGER,
    quantity INTEGER,
    unit_price REAL,
    discount_pct REAL,
    FOREIGN KEY(order_id)
    REFERENCES orders(order_id),
    FOREIGN KEY(product_id)
    REFERENCES products(product_id)
)
""")

conn.commit()

# %% [markdown]
# # Inserting Sample Data

# %%
cursor.executescript("""
INSERT INTO customers VALUES
(101, 'Aarav', 'Sharma', 'aarav.s@email.com', 'Mumbai', 'Maharashtra', '2024-01-15', 1),

(102, 'Priya', 'Patel', 'priya.p@email.com', 'Ahmedabad', 'Gujarat', '2024-02-20', 0),

(103, 'Rohan', 'Gupta', 'rohan.g@email.com', 'Delhi', 'Delhi', '2024-03-10', 1),

(104, 'Sneha', 'Reddy', 'sneha.r@email.com', 'Hyderabad', 'Telangana', '2024-04-05', 0),

(105, 'Vikram', 'Singh', 'vikram.s@email.com', 'Jaipur', 'Rajasthan', '2024-05-12', 1),

(106, 'Ananya', 'Iyer', 'ananya.i@email.com', 'Chennai', 'Tamil Nadu', '2024-06-18', 0),

(107, 'Karan', 'Mehta', 'karan.m@email.com', 'Pune', 'Maharashtra', '2024-07-22', 1),

(108, 'Divya', 'Nair', 'divya.n@email.com', 'Kochi', 'Kerala', '2024-08-30', 0);
""")

conn.commit()

# %%
cursor.executescript("""
INSERT INTO products VALUES 
(201, 'Wireless Earbuds',     'Electronics', 'BoAt',          1499.00, 250), 
(202, 'Cotton T-Shirt',       'Clothing',    'Levis',         799.00,  500), 
(203, 'Smart Watch',          'Electronics', 'Noise',         2999.00, 150), 
(204, 'Running Shoes',        'Clothing',    'Nike',          4599.00, 120), 
(205, 'Bluetooth Speaker',    'Electronics', 'JBL',           3499.00, 200), 
(206, 'Bedsheet Set',         'Home',        'Spaces',        1299.00, 300), 
(207, 'Laptop Stand',         'Electronics', 'AmazonBasics',  899.00,  180), 
(208, 'Cushion Covers (Set)', 'Home',        'HomeCenter',    599.00,  400);
""")

# %%
cursor.executescript("""
INSERT INTO orders VALUES 
(1001, 101, '2024-08-01', 'Delivered',  4498.00), 
(1002, 102, '2024-08-03', 'Delivered',  799.00), 
(1003, 103, '2024-08-05', 'Shipped',    7498.00), 
(1004, 101, '2024-08-10', 'Delivered',  3499.00), 
(1005, 104, '2024-08-12', 'Cancelled',  2999.00), 
(1006, 105, '2024-08-15', 'Delivered',  5898.00), 
(1007, 106, '2024-08-18', 'Pending',    1299.00), 
(1008, 103, '2024-08-20', 'Delivered',  899.00), 
(1009, 107, '2024-08-25', 'Shipped',    6098.00), 
(1010, 108, '2024-08-28', 'Delivered',  1598.00); 
""")

# %%
cursor.executescript("""
INSERT INTO order_items VALUES 
(5001, 1001, 201, 2, 1499.00, 0), 
(5002, 1001, 207, 1, 899.00,  10), 
(5003, 1002, 202, 1, 799.00,  0), 
(5004, 1003, 203, 1, 2999.00, 0), 
(5005, 1003, 204, 1, 4599.00, 5), 
(5006, 1004, 205, 1, 3499.00, 0), 
(5007, 1005, 203, 1, 2999.00, 0), 
(5008, 1006, 201, 1, 1499.00, 10), 
(5009, 1006, 204, 1, 4599.00, 5), 
(5010, 1007, 206, 1, 1299.00, 0), 
(5011, 1008, 207, 1, 899.00,  0), 
(5012, 1009, 205, 1, 3499.00, 0), 
(5013, 1009, 208, 2, 599.00,  15), 
(5014, 1010, 206, 1, 1299.00, 0), 
(5015, 1010, 208, 1, 599.00,  0); 
""")

# %% [markdown]
# # Verifying Tables and Data

# %%
import pandas as pd

pd.read_sql_query("""
SELECT name
FROM sqlite_master
WHERE type='table';
""", conn)
# Out:
#           name
# 0    customers
# 1     products
# 2       orders
# 3  order_items

# %% [markdown]
# # Checking Row Counts

# %%
pd.read_sql_query("""
SELECT COUNT(*) AS Total_Customers
FROM customers;
""", conn)
# Out:
#    Total_Customers
# 0                8

# %%
pd.read_sql_query("""
SELECT COUNT(*) AS Total_Products
FROM products;
""", conn)
# Out:
#    Total_Products
# 0               8

# %%
pd.read_sql_query("""
SELECT COUNT(*) AS Total_Orders
FROM orders;
""", conn)
# Out:
#    Total_Orders
# 0            10

# %%
pd.read_sql_query("""
SELECT COUNT(*) AS Total_Order_Items
FROM order_items;
""", conn)
# Out:
#    Total_Order_Items
# 0                 15

# %% [markdown]
# # Helper Function For Running SQL Queries

# %%
def run_query(query):
    return pd.read_sql_query(query, conn)

# %% [markdown]
# # Q1 Display All Customer Details

# %%
run_query("""
SELECT *
FROM customers;
""")
# Out:
#    customer_id first_name last_name               email       city  \
# 0          101      Aarav    Sharma   aarav.s@email.com     Mumbai
# 1          102      Priya     Patel   priya.p@email.com  Ahmedabad
# 2          103      Rohan     Gupta   rohan.g@email.com      Delhi
# 3          104      Sneha     Reddy   sneha.r@email.com  Hyderabad
# 4          105     Vikram     Singh  vikram.s@email.com     Jaipur
# 5          106     Ananya      Iyer  ananya.i@email.com    Chennai
# 6          107      Karan     Mehta   karan.m@email.com       Pune
# 7          108      Divya      Nair   divya.n@email.com      Kochi
#
#          state   join_date  is_premium
# 0  Maharashtra  2024-01-15           1
# 1      Gujarat  2024-02-20           0
# 2        Delhi  2024-03-10           1
# 3    Telangana  2024-04-05           0
# 4    Rajasthan  2024-05-12           1
# 5   Tamil Nadu  2024-06-18           0
# 6  Maharashtra  2024-07-22           1
# 7       Kerala  2024-08-30           0

# %% [markdown]
# # Q2 Display Customer Names and Cities

# %%
run_query("""
SELECT
first_name,
last_name,
city
FROM customers;
""")
# Out:
#   first_name last_name       city
# 0      Aarav    Sharma     Mumbai
# 1      Priya     Patel  Ahmedabad
# 2      Rohan     Gupta      Delhi
# 3      Sneha     Reddy  Hyderabad
# 4     Vikram     Singh     Jaipur
# 5     Ananya      Iyer    Chennai
# 6      Karan     Mehta       Pune
# 7      Divya      Nair      Kochi

# %% [markdown]
# # Q3 Display Unique Product Categories

# %%
run_query("""
SELECT DISTINCT category
FROM products;
""")
# Out:
#       category
# 0  Electronics
# 1     Clothing
# 2         Home

# %% [markdown]
# # Q4 Primary Keys
#
# customers → customer_id
#
# products → product_id
#
# orders → order_id
#
# order_items → item_id
#
# Primary Key uniquely identifies each record.

# %% [markdown]
# # Q5 Foreign Keys
#
# orders.customer_id → customers.customer_id
#
# order_items.order_id → orders.order_id
#
# order_items.product_id → products.product_id
#
# Foreign Keys maintain relationships between tables.

# %% [markdown]
# # verification cells

# %%
pd.read_sql_query("""
SELECT COUNT(*) FROM customers
""", conn)
# Out:
#    COUNT(*)
# 0         8

# %%
pd.read_sql_query("""
SELECT COUNT(*) FROM orders
""", conn)
# Out:
#    COUNT(*)
# 0        10

# %% [markdown]
# # Q6 Display Premium Customers

# %%
run_query("""
SELECT *
FROM customers
WHERE is_premium = 1;
""")
# Out:
#    customer_id first_name last_name               email    city        state  \
# 0          101      Aarav    Sharma   aarav.s@email.com  Mumbai  Maharashtra
# 1          103      Rohan     Gupta   rohan.g@email.com   Delhi        Delhi
# 2          105     Vikram     Singh  vikram.s@email.com  Jaipur    Rajasthan
# 3          107      Karan     Mehta   karan.m@email.com    Pune  Maharashtra
#
#     join_date  is_premium
# 0  2024-01-15           1
# 1  2024-03-10           1
# 2  2024-05-12           1
# 3  2024-07-22           1

# %% [markdown]
# # Q7 Products With Price Greater Than 1000

# %%
run_query("""
SELECT *
FROM products
WHERE unit_price > 1000;
""")
# Out:
#    product_id       product_name     category   brand  unit_price  stock_qty
# 0         201   Wireless Earbuds  Electronics    BoAt      1499.0        250
# 1         203        Smart Watch  Electronics   Noise      2999.0        150
# 2         204      Running Shoes     Clothing    Nike      4599.0        120
# 3         205  Bluetooth Speaker  Electronics     JBL      3499.0        200
# 4         206       Bedsheet Set         Home  Spaces      1299.0        300

# %% [markdown]
# # Q8 Orders Placed After August 15 2024

# %%
run_query("""
SELECT *
FROM orders
WHERE order_date > '2024-08-15';
""")
# Out:
#    order_id  customer_id  order_date     status  total_amount
# 0      1007          106  2024-08-18    Pending        1299.0
# 1      1008          103  2024-08-20  Delivered         899.0
# 2      1009          107  2024-08-25    Shipped        6098.0
# 3      1010          108  2024-08-28  Delivered        1598.0

# %% [markdown]
# # Q9 Customers From Maharashtra

# %%
run_query("""
SELECT *
FROM customers
WHERE state = 'Maharashtra';
""")
# Out:
#    customer_id first_name last_name              email    city        state  \
# 0          101      Aarav    Sharma  aarav.s@email.com  Mumbai  Maharashtra
# 1          107      Karan     Mehta  karan.m@email.com    Pune  Maharashtra
#
#     join_date  is_premium
# 0  2024-01-15           1
# 1  2024-07-22           1

# %% [markdown]
# # Q10 Orders Between 2000 and 6000

# %%
run_query("""
SELECT *
FROM orders
WHERE total_amount BETWEEN 2000 AND 6000;
""")
# Out:
#    order_id  customer_id  order_date     status  total_amount
# 0      1001          101  2024-08-01  Delivered        4498.0
# 1      1004          101  2024-08-10  Delivered        3499.0
# 2      1005          104  2024-08-12  Cancelled        2999.0
# 3      1006          105  2024-08-15  Delivered        5898.0

# %% [markdown]
# # Q11 Difference Between WHERE and HAVING
#
# WHERE filters rows before aggregation.
#
# HAVING filters groups after aggregation.
#
# Example:
#
# WHERE Sales > 1000
#
# HAVING SUM(Sales) > 5000

# %% [markdown]
# # Q12 Difference Between COUNT(*) and COUNT(column)
#
# COUNT(*) counts all rows.
#
# COUNT(column) counts only non-null values in that column.

# %% [markdown]
# # Q13 Total Sales Amount

# %%
run_query("""
SELECT
SUM(total_amount) AS Total_Sales
FROM orders;
""")
# Out:
#    Total_Sales
# 0      35085.0

# %% [markdown]
# # Q14 Average Product Price

# %%
run_query("""
SELECT
AVG(unit_price) AS Average_Price
FROM products;
""")
# Out:
#    Average_Price
# 0         2024.0

# %% [markdown]
# # Q15 Total Orders Per Customer

# %%
run_query("""
SELECT
customer_id,
COUNT(order_id) AS Total_Orders
FROM orders
GROUP BY customer_id;
""")
# Out:
#    customer_id  Total_Orders
# 0          101             2
# 1          102             1
# 2          103             2
# 3          104             1
# 4          105             1
# 5          106             1
# 6          107             1
# 7          108             1

# %% [markdown]
# # Q16 Total Revenue By Product Category

# %%
run_query("""
SELECT
category,
SUM(unit_price) AS Revenue
FROM products
GROUP BY category;
""")
# Out:
#       category  Revenue
# 0     Clothing   5398.0
# 1  Electronics   8896.0
# 2         Home   1898.0

# %% [markdown]
# # Q17 Maximum Product Price In Each Category

# %%
run_query("""
SELECT
category,
MAX(unit_price) AS Max_Price
FROM products
GROUP BY category;
""")
# Out:
#       category  Max_Price
# 0     Clothing     4599.0
# 1  Electronics     3499.0
# 2         Home     1299.0

# %% [markdown]
# # Q18 Total Quantity Sold Per Product

# %%
run_query("""
SELECT
product_id,
SUM(quantity) AS Total_Quantity
FROM order_items
GROUP BY product_id;
""")
# Out:
#    product_id  Total_Quantity
# 0         201               3
# 1         202               1
# 2         203               2
# 3         204               2
# 4         205               2
# 5         206               2
# 6         207               2
# 7         208               3

# %% [markdown]
# # Q19 Top 5 Most Expensive Products

# %%
run_query("""
SELECT *
FROM products
ORDER BY unit_price DESC
LIMIT 5;
""")
# Out:
#    product_id       product_name     category   brand  unit_price  stock_qty
# 0         204      Running Shoes     Clothing    Nike      4599.0        120
# 1         205  Bluetooth Speaker  Electronics     JBL      3499.0        200
# 2         203        Smart Watch  Electronics   Noise      2999.0        150
# 3         201   Wireless Earbuds  Electronics    BoAt      1499.0        250
# 4         206       Bedsheet Set         Home  Spaces      1299.0        300

# %% [markdown]
# # Q20 Latest 3 Orders

# %%
run_query("""
SELECT *
FROM orders
ORDER BY order_date DESC
LIMIT 3;
""")
# Out:
#    order_id  customer_id  order_date     status  total_amount
# 0      1010          108  2024-08-28  Delivered        1598.0
# 1      1009          107  2024-08-25    Shipped        6098.0
# 2      1008          103  2024-08-20  Delivered         899.0

# %% [markdown]
# # Q21 Customer Wise Total Spending

# %%
run_query("""
SELECT
c.customer_id,
c.first_name,
c.last_name,
SUM(o.total_amount) AS Total_Spending
FROM customers c
JOIN orders o
ON c.customer_id = o.customer_id
GROUP BY c.customer_id
ORDER BY Total_Spending DESC;
""")
# Out:
#    customer_id first_name last_name  Total_Spending
# 0          103      Rohan     Gupta          8397.0
# 1          101      Aarav    Sharma          7997.0
# 2          107      Karan     Mehta          6098.0
# 3          105     Vikram     Singh          5898.0
# 4          104      Sneha     Reddy          2999.0
# 5          108      Divya      Nair          1598.0
# 6          106     Ananya      Iyer          1299.0
# 7          102      Priya     Patel           799.0

# %% [markdown]
# # Q22 Difference Between INNER JOIN and LEFT JOIN
#
# INNER JOIN returns only matching records from both tables.
#
# LEFT JOIN returns all records from the left table and matching records from the right table.
#
# If no match exists, NULL values are returned from the right table.

# %% [markdown]
# # Q23 Monthly Sales Trend

# %%
run_query("""
SELECT
strftime('%Y-%m', order_date) AS Month,
SUM(total_amount) AS Total_Sales
FROM orders
GROUP BY Month
ORDER BY Month;
""")
# Out:
#      Month  Total_Sales
# 0  2024-08      35085.0

# %% [markdown]
# # Q24 Orders By Status

# %%
run_query("""
SELECT
status,
COUNT(*) AS Total_Orders
FROM orders
GROUP BY status;
""")
# Out:
#       status  Total_Orders
# 0  Cancelled             1
# 1  Delivered             6
# 2    Pending             1
# 3    Shipped             2

# %% [markdown]
# # Q25 Premium Customer Orders

# %%
run_query("""
SELECT
c.first_name,
c.last_name,
o.order_id,
o.total_amount
FROM customers c
JOIN orders o
ON c.customer_id = o.customer_id
WHERE c.is_premium = 1;
""")
# Out:
#   first_name last_name  order_id  total_amount
# 0      Aarav    Sharma      1001        4498.0
# 1      Rohan     Gupta      1003        7498.0
# 2      Aarav    Sharma      1004        3499.0
# 3     Vikram     Singh      1006        5898.0
# 4      Rohan     Gupta      1008         899.0
# 5      Karan     Mehta      1009        6098.0

# %% [markdown]
# # Q26 Find Duplicate Emails

# %%
run_query("""
SELECT
email,
COUNT(*) AS Count_Email
FROM customers
GROUP BY email
HAVING COUNT(*) > 1;
""")
# Out:
# Empty DataFrame
# Columns: [email, Count_Email]
# Index: []

# %% [markdown]
# # Q27 Data Validation Checks

# %%
run_query("""
SELECT COUNT(*) AS Total_Customers
FROM customers;
""")
# Out:
#    Total_Customers
# 0                8

# %%
run_query("""
SELECT COUNT(*) AS Total_Products
FROM products;
""")
# Out:
#    Total_Products
# 0               8

# %%
run_query("""
SELECT COUNT(*) AS Total_Orders
FROM orders;
""")
# Out:
#    Total_Orders
# 0            10

# %%
run_query("""
SELECT COUNT(*) AS Total_Order_Items
FROM order_items;
""")
# Out:
#    Total_Order_Items
# 0                 15

# %% [markdown]
# # Business Insights
#
# 1. Premium customers contribute significantly to overall sales.
# 2. Product categories show different revenue contributions.
# 3. Monthly sales trends help identify business performance.
# 4. Order status analysis helps track operational efficiency.
# 5. No duplicate customer emails were found, indicating good data quality.
